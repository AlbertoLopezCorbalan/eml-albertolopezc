# %% [markdown]
# [<img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> Main](https://colab.research.google.com/github/AlbertoLopezCorbalan/eml-albertolopezc/blob/main/k_brazos/main.ipynb)
#
#
# # Estudio comparativo del problema de k-brazos y entornos complejos
#
# - **Alumno:** López Corbalán, Alberto
# - **Asignatura:** Extensiones de Machine Learning
# - **Curso:** 2025/2026
# - **Grupo:** albertolopezc
#
# ## Estructura del repositorio de k_brazos
#
# ```text
# albertolopezc/
# ├── informe.pdf                    # Informe técnico
# ├── main.ipynb                     # Notebook principal que enlaza y organiza todas las partes del proyecto
# │
# ├── k_brazos/
# │   ├── src/                       # Código fuente (.py)
# │   ├── main.ipynb                 # Notebook principal de esta sección enlaces a los estudios realizados
# │   ├── epsilon-greedy.ipynb
# │   ├── epsilon-greedy-decay.ipynb
# │   ├── epsilon-greedy-exploration.ipynb
# │   ├── UCB1.ipynb
# │   └── softmax.ipynb
# │
# └── Entornos_Complejos/
#     ├── src/                       # Código fuente (.py)
#     ├── main.ipynb                 # Notebook principal de esta sección con enlaces a los estudios realizados
#     ├── deep_q_learning.ipynb
#     ├── gymnasium_test.ipynb
#     ├── monte_carlo.ipynb
#     ├── q_learning.ipynb
#     ├── sarsa.ipynb
#     └── sarsa_semi_gradient.ipynb
# ```
#
# ## Descripción
#
# Este notebook (`main.ipynb`) actúa como **punto de entrada principal del proyecto**, organizando y enlazando las dos partes del trabajo:
#
# - **k_brazos**: estudio del problema del bandido multi-brazo. [<img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> k_brazos](https://colab.research.google.com/github/AlbertoLopezCorbalan/eml-albertolopezc/blob/main/k_brazos/main.ipynb)
# - **Entornos_Complejos**: implementación y análisis de algoritmos de aprendizaje por refuerzo en entornos tabulares y aproximados. [<img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> Entornos_Complejos](https://colab.research.google.com/github/AlbertoLopezCorbalan/eml-albertolopezc/blob/main/Entornos_Complejos/main.ipynb)
#
# **¿Cómo ejecutar los experimentos?**
#
# 1. Abre el notebook deseado haciendo clic en su enlace.
# 2. En Colab, selecciona **"Entorno de ejecución > Ejecutar todas"** .
